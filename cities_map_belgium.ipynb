# %%
#!pip install cartopy

# %%
#!pip install folium

# %%
import folium
import pandas as pd

# %%
df_cities_NIS = pd.read_csv('cities_NIS_dataset.csv')
df_cities_NIS.head(10)
# Out:
#    ID        Name  Habitants    Index Acreage  HabitantsPerSquareKm  \
# 0   1   Antwerpen    525.935  443.000  204,51                 2.572
# 1   2        Gent    262.219  204.000  156,18                 1.679
# 2   3   Charleroi    202.267  370.000  102,08                 1.982
# 3   4       Liège    197.327  219.000   69,39                 2.844
# 4   5     Brussel    181.726  140.000   32,61                 5.573
# 5   6  Schaarbeek    133.309    2.146    8,14                16.377
# 6   7  Anderlecht    119.714    2.007   17,74                 6.747
# 7   8      Brugge    118.325  194.000  138,40               855.000
# 8   9       Namur    110.779  260.000  175,69               631.000
# 9  10      Leuven    101.624  288.000   56,63                 1.794
#
#   ProsperityIndex         Province   Latitude  Longitude  \
# 0            88,2        Antwerpen  51.221110   4.399708
# 1           102,3  Oost-Vlaanderen  51.053829   3.725012
# 2            73,0       Henegouwen  50.412033   4.443624
# 3            81,4             Luik  50.645138   5.573420
# 4            70,0          Brussel  50.846557   4.351697
# 5            65,4          Brussel  50.867604   4.373712
# 6            63,8          Brussel  50.839098   4.329653
# 7           111,7  West-Vlaanderen  51.208553   3.226772
# 8            99,9            Namen  50.466528   4.866189
# 9           113,6   Vlaams-Brabant  50.879202   4.701168
#
#                                          BoundingBox       Frans  Nederlands  \
# 0  ['51.1432868', '51.3776412', '4.2175769', '4.4...      Anvers   Antwerpen
# 1  ['50.9795422', '51.187946', '3.5797616', '3.84...        Gand        Gent
# 2  ['50.3527894', '50.4925149', '4.3474458', '4.5...   Charleroi           -
# 3  ['50.5610182', '50.6881981', '5.5233883', '5.6...       Liège        Luik
# 4  ['50.6865573', '51.0065573', '4.191697', '4.51...   Bruxelles     Brussel
# 5  ['50.8434069', '50.8811977', '4.3571322', '4.4...  Schaerbeek  Schaarbeek
# 6  ['50.8070598', '50.850549', '4.2437658', '4.34...  Anderlecht  Anderlecht
# 7  ['51.1581918', '51.363347', '3.1341802', '3.30...      Bruges      Brugge
# 8  ['50.3872825', '50.5313007', '4.723053', '4.98...       Namur       Namen
# 9  ['50.8242096', '50.9440707', '4.640295', '4.77...     Louvain      Leuven
#
#        Duits       Begin       Einde
# 0  Antwerpen  01.01.0001  31.12.9999
# 1       Gent  01.01.0001  31.12.9999
# 2          -  01.01.0001  31.12.9999
# 3    Lüttich  01.01.0001  31.12.9999
# 4          -  01.01.0001  31.12.9999
# 5          -  01.01.0001  31.12.9999
# 6          -  01.01.0001  31.12.9999
# 7     Brügge  01.01.0001  31.12.9999
# 8          -  01.01.0001  31.12.9999
# 9      Löwen  01.01.0001  31.12.9999

# %%
df_nan = df_cities_NIS[df_cities_NIS.isna().any(axis=1)]
df_nan
# Out:
#       ID               Name  Habitants  Index Acreage  HabitantsPerSquareKm  \
# 26    26           Mouscron     58.474  426.0   40,08                 1.459
# 73    72               Pelt     32.902  967.0   83,62               393.000
# 102  102           Lievegem     26.162  133.0   80,17               326.000
# 104  105  Puurs-Sint-Amands     25.882  210.0   48,99               528.000
# 121  123         Oudsbergen     23.532  781.0  116,24               202.000
# 179  181           Lessines     18.656  108.0   72,29               258.000
# 192  193   Comines-Warneton     18.271  169.0   61,09               295.000
# 224  225            Kruisem     15.641   87.0   70,69               221.000
# 256  259            Enghien     13.817  171.0   40,59               340.000
# 404  409              Silly      8.324   94.0   67,68               123.000
#
#     ProsperityIndex         Province   Latitude  Longitude  \
# 26             84,3       Henegouwen  50.743335   3.213909
# 73              NaN          Limburg  51.219767   5.429950
# 102             NaN  Oost-Vlaanderen  51.124810   3.585182
# 104             NaN        Antwerpen  51.066411   4.281235
# 121             NaN          Limburg  51.093315   5.554075
# 179            92,3       Henegouwen  50.712304   3.830113
# 192            82,9       Henegouwen  50.768305   3.000117
# 224             NaN  Oost-Vlaanderen  50.908554   3.564892
# 256           105,8       Henegouwen  50.695707   4.041193
# 404           110,1       Henegouwen  50.648454   3.923592
#
#                                            BoundingBox             Frans  \
# 26   ['50.7099086', '50.7658775', '3.1783878', '3.3...          Mouscron
# 73   ['51.1642606', '51.2763994', '5.3201395', '5.5...               NaN
# 102  ['51.074142', '51.17538', '3.5096511', '3.6669...               NaN
# 104  ['51.0266328', '51.1021234', '4.1864725', '4.3...               NaN
# 121  ['51.0188206', '51.1463397', '5.4544044', '5.6...                 -
# 179  ['50.6693987', '50.7516088', '3.745127', '3.91...          Lessines
# 192  ['50.6923535', '50.810512', '2.8420347', '3.02...  Comines-Warneton
# 224  ['50.8698154', '50.9530743', '3.4665418', '3.6...               NaN
# 256  ['50.6307227', '50.713668', '3.9612715', '4.11...           Enghien
# 404  ['50.5902435', '50.6954989', '3.8765388', '4.0...             Silly
#
#             Nederlands Duits       Begin       Einde
# 26           Moeskroen   NaN  01.01.2019  31.12.9999
# 73                Pelt   NaN  01.01.2019  31.12.9999
# 102           Lievegem   NaN  01.01.2019  31.12.9999
# 104  Puurs-Sint-Amands   NaN  01.01.2019  31.12.9999
# 121         Oudsbergen     -  01.01.2019  31.12.9999
# 179             Lessen   NaN  01.01.2019  31.12.9999
# 192      Komen-Waasten   NaN  01.01.2019  31.12.9999
# 224            Kruisem   NaN  01.01.2019  31.12.9999
# 256            Edingen   NaN  01.01.2019  31.12.9999
# 404           Opzullik   NaN  01.01.2019  31.12.9999

# %%
df_cities_NIS['Name'].replace(
    {'Brussel': 'Brussel#Bruxelles',
    'Elsene': 'Elsene#Ixelles',
    'Oudergem': 'Oudergem#Auderghem',
    'Schaarbeek': 'Schaarbeek#Schaerbeek',
    'Sint-Agatha-Berchem': 'Sint-Agatha-Berchem#Berchem-Sainte-Agathe',
    'Sint-Gillis': 'Sint-Gillis#Saint-Gilles',
    'Sint-Jan-Molenbeek': 'Sint-Jan-Molenbeek#Molenbeek-Saint-Jean',
    'Sint-Joost-ten-Node': 'Sint-Joost-ten-Node#Saint-Josse-ten-Noode',
    'Sint-Lambrechts-Woluwe': 'Sint-Lambrechts-Woluwe#Woluwe-Saint-Lambert',
    'Sint-Pieters-Woluwe': 'Sint-Pieters-Woluwe#Woluwe-Saint-Pierre',
    'Ukkel': 'Ukkel#Uccle',
    'Vorst': 'Vorst#Forest',
    'Watermaal-Bosvoorde': 'Watermaal-Bosvoorde#Watermael-Boitsfort',
    'Bever': 'Bever#Biévène',
    'Sint-Genesius-Rode': 'Sint-Genesius-Rode#Rhode-Saint-Genèse',
    'Voeren': 'Voeren#Fourons',
    'Ronse': 'Ronse#Renaix',
    'Mesen': 'Mesen#Messines',
    'Spiere-Helkijn': 'Spiere-Helkijn#Espierres-Helchin',
    'Comines-Warneton': 'Comines-Warneton#Komen-Waasten',
    'Enghien': 'Enghien#Edingen',
    'Flobecq': 'Flobecq#Vloesberg',
    'Mouscron': 'Mouscron#Moeskroen',
    'Amel': 'Amel#Amblève',
    'Büllingen': 'Büllingen#Bullange',
    'Bütgenbach': 'Bütgenbach#Butgenbach',
    'Kelmis': 'Kelmis#La Calamine',
    'Sankt Vith': 'Sankt Vith#Saint-Vith',
    'Waimes': 'Waimes#Weismes',
    'Kruisem': 'Kruishoutem',
    'Bergen': 'Mons',
    'Deinze*': 'Deinze',
    'Aalter*': 'Aalter'},
    regex=True,inplace=True)

# %%
df_prosp_idx = df_cities_NIS.dropna(subset=['ProsperityIndex'])
df_prosp_idx['ProsperityIndex'].replace({',': '.'}, regex=True,inplace=True)
df_prosp_idx['ProsperityIndex'] = pd.to_numeric(df_prosp_idx['ProsperityIndex'])
df_prosp_idx.dtypes
# Out:
# C:\Tools\Anaconda3\lib\site-packages\pandas\core\generic.py:5886: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._update_inplace(new_data)
# C:\Tools\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# ID                        int64
# Name                     object
# Habitants               float64
# Index                   float64
# Acreage                  object
# HabitantsPerSquareKm    float64
# ProsperityIndex         float64
# Province                 object
# Latitude                float64
# Longitude               float64
# BoundingBox              object
# Frans                    object
# Nederlands               object
# Duits                    object
# Begin                    object
# Einde                    object
# dtype: object

# %%
df_nan = df_prosp_idx[df_prosp_idx.isna().any(axis=1)]
df_nan
# Out:
#       ID                            Name  Habitants  Index Acreage  \
# 26    26              Mouscron#Moeskroen     58.474  426.0   40,08
# 179  181                        Lessines     18.656  108.0   72,29
# 192  193  Comines-Warneton#Komen-Waasten     18.271  169.0   61,09
# 256  259                 Enghien#Edingen     13.817  171.0   40,59
# 404  409                           Silly      8.324   94.0   67,68
#
#      HabitantsPerSquareKm  ProsperityIndex    Province   Latitude  Longitude  \
# 26                  1.459             84.3  Henegouwen  50.743335   3.213909
# 179               258.000             92.3  Henegouwen  50.712304   3.830113
# 192               295.000             82.9  Henegouwen  50.768305   3.000117
# 256               340.000            105.8  Henegouwen  50.695707   4.041193
# 404               123.000            110.1  Henegouwen  50.648454   3.923592
#
#                                            BoundingBox             Frans  \
# 26   ['50.7099086', '50.7658775', '3.1783878', '3.3...          Mouscron
# 179  ['50.6693987', '50.7516088', '3.745127', '3.91...          Lessines
# 192  ['50.6923535', '50.810512', '2.8420347', '3.02...  Comines-Warneton
# 256  ['50.6307227', '50.713668', '3.9612715', '4.11...           Enghien
# 404  ['50.5902435', '50.6954989', '3.8765388', '4.0...             Silly
#
#         Nederlands Duits       Begin       Einde
# 26       Moeskroen   NaN  01.01.2019  31.12.9999
# 179         Lessen   NaN  01.01.2019  31.12.9999
# 192  Komen-Waasten   NaN  01.01.2019  31.12.9999
# 256        Edingen   NaN  01.01.2019  31.12.9999
# 404       Opzullik   NaN  01.01.2019  31.12.9999

# %%
be_geo = r'municipalities-belgium.geojson' # geojson file
latitude = 50.85045 - 0.40
longitude = 4.34878
# create a plain world map
#world_map = folium.Map(location=[0, 0], zoom_start=2, tiles='Mapbox Bright')
map_be = folium.Map(location=[latitude, longitude], zoom_start=8)
map_be
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
be_geo = r'municipalities-belgium.geojson' # geojson file
latitude = 50.85045 - 0.40
longitude = 4.34878
# create a plain world map
#world_map = folium.Map(location=[0, 0], zoom_start=2, tiles='Mapbox Bright')
map_be = folium.Map(location=[latitude, longitude], zoom_start=8)

# BuGn, BuPu, GnBu, OrRd, PuBu, PuBuGn, PuRd, RdPu, YlGn, YlGnBu, YlOrBr, and YlOrRd
# nan_fill_color and nan_fill_opacity
map_be.choropleth(
    geo_data=be_geo,
    data=df_prosp_idx,
    columns=['Name', 'ProsperityIndex'],
    key_on='feature.properties.name',
    fill_color='PuBuGn', 
    fill_opacity=0.5, 
    line_opacity=0.2,
    nan_fill_opacity=0.5,
    nan_fill_color='white',
    legend_name='Prosperity index Belgium')
map_be
# Out:
# C:\Tools\Anaconda3\lib\site-packages\folium\folium.py:415: FutureWarning: The choropleth  method has been deprecated. Instead use the new Choropleth class, which has the same arguments. See the example notebook 'GeoJSON_and_choropleth' for how to do this.
#   FutureWarning
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# create map of Belgium using latitude and longitude values


# add markers to map
for lat, lng, borough, neighborhood in zip(neighborhoods['Latitude'], neighborhoods['Longitude'], neighborhoods['Borough'], neighborhoods['Neighborhood']):
    label = '{}, {}'.format(neighborhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=7,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_newyork)  
    
map_newyork
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-871c65bc9f0d> in <module>()
#       3
#       4 # add markers to map
# ----> 5 for lat, lng, borough, neighborhood in zip(neighborhoods['Latitude'], neighborhoods['Longitude'], neighborhoods['Borough'], neighborhoods['Neighborhood']):
#       6     label = '{}, {}'.format(neighborhood, borough)
#       7     label = folium.Popup(label, parse_html=True)
#
# NameError: name 'neighborhoods' is not defined
