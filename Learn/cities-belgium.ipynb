# %% [markdown]
# !conda install -c conda-forge beautifulsoup4 --yes

# %% [markdown]
# !conda install -c conda-forge geopy --yes

# %% [markdown]
# !pip install geopy

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup
from geopy.geocoders import Nominatim

# %%
cities_page = 'https://nl.wikipedia.org/wiki/Tabel_van_Belgische_gemeenten'

# %%
req = requests.get(cities_page)
print(req.encoding)
req.status_code
# Out:
# UTF-8
# 200

# %%
#req.text

# %%
soup = BeautifulSoup(req.text, 'html.parser')
#print(soup.prettify())

# %%
#soup

# %%
data = []
table = soup.find('table', attrs={'class':'wikitable sortable'})
#print(table)
table_body = table.find('tbody')

rows = table_body.find_all('tr')
for row in rows:
    cols = row.find_all('td')
    cols = [ele.text.strip() for ele in cols]
    #data.append([ele for ele in cols if ele])
    data.append([ele for ele in cols])

# %%
# Create dataframe from list
# first row is empty. Code will break if this changes!
df_cities = pd.DataFrame(data[1:])
print(df_cities.shape)
df_cities.head(50)
# Out:
# (581, 16)
#     0                       1        2        3        4        5        6   \
# 0    1               Antwerpen  118.682  383.557  526.396  446.525  525.935
# 1    2                    Gent  128.828  222.895  254.216  224.180  262.219
# 2    3               Charleroi   54.694  198.837  233.737  200.827  202.267
# 3    4                    Luik   89.943  206.384  231.502  185.639  197.327
# 4    5                 Brussel  129.680  218.623  184.838  133.859  181.726
# 5    6              Schaarbeek    6.211   63.508  123.671  105.692  133.309
# 6    7              Anderlecht    5.966   47.929   86.412   87.812  119.714
# 7    8                  Brugge   60.855   70.277   93.062  116.264  118.325
# 8    9                   Namen   42.529   62.427   77.584  105.419  110.779
# 9   10                  Leuven   35.334   58.523   67.322   88.014  101.624
# 10  11     Sint-Jans-Molenbeek   12.065   58.445   63.922   71.219   97.462
# 11  12                  Bergen   52.106   77.263   84.072   90.935   95.613
# 12  13                  Elsene   14.251   58.615   90.711   73.174   86.876
# 13  14                Mechelen   36.915   64.781   72.232   75.438   86.616
# 14  15                   Aalst   32.910   50.500   73.147   84.859   86.445
# 15  16                   Ukkel    6.372   18.034   56.156   74.221   83.024
# 16  17             La Louvière   16.726   57.594   73.901   76.568   80.757
# 17  18                 Hasselt   15.229   20.812   41.301   68.058   78.296
# 18  19            Sint-Niklaas   29.966   42.672   57.846   68.290   77.769
# 19  20                Kortrijk   35.144   50.540   65.179   74.790   76.735
# 20  21                Oostende   16.022   41.547   56.514   67.279   71.494
# 21  22                 Doornik   65.609   70.343   68.443   67.379   69.370
# 22  23                    Genk    1.776    2.537   33.858   62.842   66.227
# 23  24                 Seraing   17.236   63.068   77.219   60.557   64.259
# 24  25               Roeselare   21.563   33.688   44.011   54.199   62.954
# 25  26               Moeskroen   13.713   28.773   52.245   52.492   58.474
# 26  27  Sint-Lambrechts-Woluwe    1.182    3.468   26.344   46.528   56.660
# 27  28                   Vorst    1.324    9.509   47.370   45.555   56.289
# 28  29                Verviers   34.463   69.094   60.634   53.148   55.207
# 29  30                   Jette    1.981   10.053   29.484   39.749   52.536
# 30  31             Sint-Gillis    4.138   51.763   61.396   42.458   50.267
# 31  32                 Beveren   24.723   29.847   35.829   44.977   48.668
# 32  33               Etterbeek    3.084   20.838   50.040   39.404   48.367
# 33  34                Beringen    7.881    7.495   19.794   39.261   46.346
# 34  35             Dendermonde   20.184   28.937   38.832   43.137   45.769
# 35  36               Vilvoorde    6.869   14.075   27.529   34.982   44.727
# 36  37                Turnhout   14.396   20.887   32.135   38.596   44.664
# 37  38                 Deinze*   28.098   27.459   29.692   38.552   43.571
# 38  39                 Dilbeek    6.727    8.471   16.685   37.722   42.847
# 39  40       Heist-op-den-Berg   12.128   15.649   26.399   37.233   42.681
# 40  41     Sint-Pieters-Woluwe    1.318    2.686   18.455   37.922   41.824
# 41  42                   Evere    1.377    3.892   15.277   31.348   41.763
# 42  43                 Lokeren   21.493   26.781   31.001   36.458   41.690
# 43  44            Sint-Truiden   17.861   23.240   30.726   37.147   40.590
# 44  45                    Geel   10.234   13.070   22.295   33.677   40.353
# 45  46             Eigenbrakel    7.674   10.957   14.881   35.259   40.008
# 46  47                 Herstal   10.654   24.273   35.998   36.292   39.989
# 47  48                   Halle   10.276   18.286   27.087   33.655   39.540
# 48  49                  Ninove   19.188   23.809   30.397   34.559   38.911
# 49  50            Maasmechelen    4.949    6.433   20.176   35.430   38.516
#
#      7      8      9      10     11      12      13     14               15
# 0   100    323    444    376    443  204,51   2.572   88,2        Antwerpen
# 1   100    173    197    174    204  156,18   1.679  102,3  Oost-Vlaanderen
# 2   100    364    427    367    370  102,08   1.982   73,0       Henegouwen
# 3   100    229    257    206    219   69,39   2.844   81,4             Luik
# 4   100    169    143    103    140   32,61   5.573   70,0          Brussel
# 5   100  1.023  1.991  1.702  2.146    8,14  16.377   65,4          Brussel
# 6   100    803  1.448  1.472  2.007   17,74   6.747   63,8          Brussel
# 7   100    115    153    191    194  138,40     855  111,7  West-Vlaanderen
# 8   100    147    182    248    260  175,69     631   99,9            Namen
# 9   100    166    191    249    288   56,63   1.794  113,6   Vlaams-Brabant
# 10  100    484    530    590    808    5,89  16.542   57,1          Brussel
# 11  100    148    161    175    183  146,53     653   88,1       Henegouwen
# 12  100    411    637    513    610    6,34  13.693   89,7          Brussel
# 13  100    175    196    204    235   65,19   1.329  104,8        Antwerpen
# 14  100    153    222    232    263   78,12   1.107  107,6  Oost-Vlaanderen
# 15  100    283    881  1.165  1.303   22,91   3.624  112,9          Brussel
# 16  100    344    442    458    483   64,24   1.257   79,8       Henegouwen
# 17  100    137    271    447    514  102,24     766  113,2          Limburg
# 18  100    142    193    228    259   83,80     927   99,3  Oost-Vlaanderen
# 19  100    144    185    213    218   80,02     959  104,5  West-Vlaanderen
# 20  100    259    353    420    446   37,72   1.895  100,3  West-Vlaanderen
# 21  100    107    104    103    106  213,75     325   94,8       Henegouwen
# 22  100    143  1.906  3.538  3.728   87,85     754   89,5          Limburg
# 23  100    366    448    351    373   35,34   1.819   77,5             Luik
# 24  100    156    204    251    292   59,79   1.053  102,1  West-Vlaanderen
# 25  100    210    381    383    426   40,08   1.459   84,3       Henegouwen
# 26  100    293  2.229  3.936  4.794    7,22   7.842   94,9          Brussel
# 27  100    718  3.578  3.441  4.251    6,25   9.009   81,4          Brussel
# 28  100    200    176    154    160   33,07   1.669   77,9             Luik
# 29  100    507  1.488  2.007  2.652    5,04  10.417   82,4          Brussel
# 30  100  1.251  1.484  1.196  1.215    2,52  19.910   70,6          Brussel
# 31  100    121    145    182    197  150,18     324  113,7  Oost-Vlaanderen
# 32  100    676  1.623  1.278  1.568    3,15  15.358   81,2          Brussel
# 33  100     95    251    498    588   78,30     592   94,4          Limburg
# 34  100    143    192    214    227   55,67     822  108,3  Oost-Vlaanderen
# 35  100    205    401    509    651   21,48   2.083   96,0   Vlaams-Brabant
# 36  100    145    223    268    310   56,06     797   97,3        Antwerpen
# 37  100     98    106    137    155  127,43     342         Oost-Vlaanderen
# 38  100    126    248    561    637   41,18   1.041  119,8   Vlaams-Brabant
# 39  100    129    218    307    352   86,46     494  108,0        Antwerpen
# 40  100    204  1.400  2.877  3.173    8,85   4.725  112,2          Brussel
# 41  100    283  1.109  2.277  3.033    5,02   8.322   74,8          Brussel
# 42  100    125    144    170    194   67,50     618  102,7  Oost-Vlaanderen
# 43  100    130    172    208    227  106,90     380  103,8          Limburg
# 44  100    128    218    329    394  109,85     367  108,9        Antwerpen
# 45  100    143    194    459    521   52,12     768  116,8    Waals-Brabant
# 46  100    228    338    341    375   23,54   1.699   80,2             Luik
# 47  100    178    264    328    385   44,40     890  107,0   Vlaams-Brabant
# 48  100    124    158    180    203   72,57     536  106,0  Oost-Vlaanderen
# 49  100    130    408    716    778   76,28     505   85,1          Limburg

# %%
df_cities.drop(columns=[2,3,4,5,7,8,9,10],inplace=True)
df_cities.columns = ['ID','Name','Habitants','Index','Acreage','HabitantsPerSquareKm','ProsperityIndex','Province']
df_cities.head()
# Out:
#   ID       Name Habitants Index Acreage HabitantsPerSquareKm ProsperityIndex  \
# 0  1  Antwerpen   525.935   443  204,51                2.572            88,2
# 1  2       Gent   262.219   204  156,18                1.679           102,3
# 2  3  Charleroi   202.267   370  102,08                1.982            73,0
# 3  4       Luik   197.327   219   69,39                2.844            81,4
# 4  5    Brussel   181.726   140   32,61                5.573            70,0
#
#           Province
# 0        Antwerpen
# 1  Oost-Vlaanderen
# 2       Henegouwen
# 3             Luik
# 4          Brussel

# %%
df_cities['Name'].replace({'*': ''}, inplace=True)

# %%
df_cities.head()
# Out:
#   ID       Name Habitants Index Acreage HabitantsPerSquareKm ProsperityIndex  \
# 0  1  Antwerpen   525.935   443  204,51                2.572            88,2
# 1  2       Gent   262.219   204  156,18                1.679           102,3
# 2  3  Charleroi   202.267   370  102,08                1.982            73,0
# 3  4       Luik   197.327   219   69,39                2.844            81,4
# 4  5    Brussel   181.726   140   32,61                5.573            70,0
#
#           Province
# 0        Antwerpen
# 1  Oost-Vlaanderen
# 2       Henegouwen
# 3             Luik
# 4          Brussel

# %% [markdown]
# city_loc_url = 'http://www.gemeentezoeker.be/developer.php'

# %% [markdown]
# req = requests.get(city_loc_url)
# print(req.encoding)
# req.status_code

# %% [markdown]
# soup_city_loc = BeautifulSoup(req.text, 'html.parser')
# print(soup_city_loc.prettify())

# %% [markdown]
# data_city_loc = []
# table = soup_city_loc.find('form', attrs={'id':'locator-form'})
# print(table)
# # table_body = table.find('tbody')
# table_body = table
#
# rows = table_body.find_all('tr')
# for row in rows:
#     cols = row.find_all('td')
#     cols = [ele.text.strip() for ele in cols]
#     data.append([ele for ele in cols if ele])

# %%
geoloc = Nominatim(user_agent='svendesmit')
loc = geoloc.geocode('Belgium, Lokeren',timeout=2000)
display = loc.raw['display_name']
arr = display.split(',')
arr[4]
# Out:
# ' 9160'

# %% [markdown]
# geoloc = Nominatim(user_agent='svendesmit')
# loc = geoloc.reverse('50.2211097,4.3997081',timeout=2000)
# loc.address

# %% [markdown]
# for city, lat,lon in zip(df_cities['Name'],df_cities['Latitude'],df_cities['Longitude']):
#     latlng_str = '{} , {}'.format(lat,lon)
#     loc = geoloc.reverse(latlng_str,timeout=2000)
#     print(loc.raw)

# %%
import numpy as np
lat_list = []
lng_list = []
bb_list = []
pc_list = []
for city in df_cities['Name']:
    print(city)
    lookupstr = 'Belgium, {}'.format(city)
    loc = geoloc.geocode(lookupstr,timeout=5000)
    #print(loc.raw['display_name'].split(','))
    if(loc != None):
        lat_list.append(loc.raw['lat'])
        lng_list.append(loc.raw['lon'])
        bb_list.append(loc.raw['boundingbox'])
        #pc_list.append(loc.raw['display_name'].split(',')[4])
        #print(loc.raw['display_name'].split(',')[4])
    else:
        lat_list.append(np.NaN)
        lng_list.append(np.NaN)
        bb_list.append(np.NaN)
        #pc_list.append(np.NaN)
# Out:
# Antwerpen
# Gent
# Charleroi
# Luik
# Brussel
# Schaarbeek
# Anderlecht
# Brugge
# Namen
# Leuven
# Sint-Jans-Molenbeek
# Bergen
# Elsene
# Mechelen
# Aalst
# Ukkel
# La Louvière
# Hasselt
# Sint-Niklaas
# Kortrijk
# Oostende
# Doornik
# Genk
# Seraing
# Roeselare
# Moeskroen
# Sint-Lambrechts-Woluwe
# Vorst
# Verviers
# Jette
# Sint-Gillis
# Beveren
# Etterbeek
# Beringen
# Dendermonde
# Vilvoorde
# Turnhout
# Deinze*
# Dilbeek
# Heist-op-den-Berg
# Sint-Pieters-Woluwe
# Evere
# Lokeren
# Sint-Truiden
# Geel
# Eigenbrakel
# Herstal
# Halle
# Ninove
# Maasmechelen
# Waregem
# Brasschaat
# Grimbergen
# Mol
# Lier
# Châtelet
# Evergem
# Tienen
# Ieper
# Schoten
# Waver
# Zaventem
# Sint-Pieters-Leeuw
# Lommel
# Oudergem
# Heusden-Zolder
# Binche
# Geraardsbergen
# Menen
# Asse
# Knokke-Heist
# Pelt
# Bilzen
# Ottignies-Louvain-la-Neuve
# Wevelgem
# Oudenaarde
# Courcelles
# Tongeren
# Houthalen-Helchteren
# Waterloo
# Aarschot
# Temse
# Aarlen
# Aat
# Brecht
# Aalter*
# Nijvel
# Ans
# Sambreville
# Herentals
# Harelbeke
# Izegem
# Zinnik
# Sint-Joost-ten-Node
# Andenne
# Kapellen
# Zottegem
# Ronse
# Willebroek
# Flémalle
# Tubeke
# Lievegem
# Mortsel
# Gembloers
# Puurs-Sint-Amands
# Lanaken
# Wetteren
# Oupeye
# Overijse
# Maaseik
# Beersel
# Watermaal-Bosvoorde
# Sint-Agatha-Berchem
# Westerlo
# Ganshoren
# Hamme
# Merelbeke
# Zwevegem
# Saint-Nicolas
# Diest
# Maldegem
# Oostkamp
# Oudsbergen
# Zemst
# Saint-Ghislain
# Manage
# Scherpenheuvel-Zichem
# Nijlen
# Fleurus
# Zedelgem
# Grâce-Hollogne
# Balen
# Rixensart
# Lochristi
# Tervuren
# Edegem
# Koekelberg
# Zoersel
# Frameries
# Koksijde
# 's-Gravenbrakel
# Herent
# Bornem
# Hoogstraten
# Zonhoven
# Hoei
# Eeklo
# Zele
# Kontich
# Wuustwezel
# Colfontaine
# Chaudfontaine
# Sint-Katelijne-Waver
# Dilsen-Stokkem
# Tielt
# Torhout
# Blankenberge
# Denderleeuw
# Kortenberg
# Boussu
# Erpe-Mere
# Poperinge
# Eupen
# Schilde
# Meise
# Sint-Gillis-Waas
# Middelkerke
# Lebbeke
# Jemeppe-sur-Sambre
# Morlanwelz
# Zwijndrecht
# Essen
# Diepenbeek
# Ranst
# Quaregnon
# Wervik
# Londerzeel
# Stabroek
# Lede
# Kalmthout
# Lessen
# Kasterlee
# Haaltert
# Tessenderlo
# Stekene
# Walcourt
# Sint-Genesius-Rode
# Destelbergen
# Boom
# Bredene
# Beerse
# Herzele
# Komen-Waasten
# Wezet
# Fontaine-l'Evêque
# Putte
# Herve
# Duffel
# Marche-en-Famenne
# Pont-à-Celles
# Péruwelz
# Aubange
# Soumagne
# Rotselaar
# Riemst
# Kruibeke
# Diksmuide
# Dour
# Merchtem
# Ciney
# Hannuit
# Lille
# Fléron
# Wemmel
# Peer
# Éghezée
# Laakdal
# Bree
# Bastenaken
# Landen
# Beernem
# Leopoldsburg
# Ternat
# Zulte
# Kruisem
# Malle
# Machelen
# Genepiën
# Borgworm
# Dison
# Rumst
# Bonheiden
# Ravels
# Berlare
# Tremelo
# Lummen
# Brakel
# Chapelle-lez-Herlaimont
# Anzegem
# Sprimont
# Thuin
# Haacht
# Lubbeek
# Opwijk
# Herselt
# Buggenhout
# Amay
# Hamont-Achel
# Aartselaar
# Wingene
# Wezembeek-Oppem
# Assenede
# Lasne
# Geldenaken
# Belœil
# Ichtegem
# Jabbeke
# Leuze-en-Hainaut
# Edingen
# Couvin
# Wanze
# Kraainem
# Graven
# Oud-Turnhout
# Ham-sur-Heure-Nalinnes
# Oosterzele
# Kuurne
# Dinant
# Liedekerke
# Arendonk
# Blégny
# Boechout
# Affligem
# Bocholt
# Mettet
# Zandhoven
# Esneux
# Wommelgem
# Zelzate
# Keerbergen
# Gavere
# Malmedy
# Gerpinnes
# De Haan
# Herk-de-Stad
# Kortemark
# Rochefort
# Boortmeerbeek
# Olen
# Zonnebeke
# Aywaille
# Hechtel-Eksel
# Laarne
# Anderlues
# Profondeville
# Gistel
# Kinrooi
# Steenokkerzeel
# Rijkevorsel
# Theux
# Kampenhout
# Deerlijk
# Beyne-Heusay
# Veurne
# Bernissart
# Frasnes-lez-Anvaing
# Chaumont-Gistoux
# Melle
# Wichelen
# Roosdaal
# Nieuwpoort
# Nazareth
# Hemiksem
# Berlaar
# Alken
# Staden
# Seneffe
# Retie
# Durbuy
# Virton
# Hoeilaart
# Farciennes
# Florennes
# Libramont-Chevigny
# Moorslede
# Vosselaar
# De Panne
# Ecaussines
# Grobbendonk
# Oud-Heverlee
# Kelmis
# Ingelmunster
# Damme
# Rebecq
# Borgloon
# Ham
# Meulebeke
# Borsbeek
# Waasmunster
# Raeren
# Tielt-Winge
# Aiseau-Presles
# Villers-la-Ville
# De Pinte
# Kasteelbrakel
# Court-Saint-Étienne
# Niel
# Steenput
# Blieberg
# Hulshout
# Fosses-la-Ville
# Jurbeke
# Meerhout
# Sint-Lievens-Houtem
# Spa
# Avelgem
# Begijnendijk
# Montigny-le-Tilleul
# Houthulst
# Bierbeek
# Holsbeek
# Bertem
# Erquelinnes
# Welkenraedt
# Hooglede
# Neupré
# Huldenberg
# Wijnegem
# Chimay
# Pepinster
# Sankt Vith
# Ledegem
# Hoeselt
# Wielsbeke
# Dessel
# Les Bons Villers
# Halen
# Kapelle-op-den-Bos
# Oudenburg
# Awans
# Perwijs
# Juprelle
# Philippeville
# La Bruyère
# Gooik
# Yvoir
# Beauraing
# Lennik
# Herenthout
# Ardooie
# Lichtervelde
# Orp-Jauche
# Bitsingen
# Bertrix
# Koekelare
# Galmaarden
# Lint
# Le Roeulx
# Merksplas
# Jalhay
# Dentergem
# Schelle
# Zoutleeuw
# Kortessem
# Sombreffe
# Habay
# Gingelom
# Sint-Martens-Latem
# Opzullik
# Boutersem
# Messancy
# As
# Trooz
# Zwalm
# Floreffe
# Quévy
# Hove
# Brunehaut
# Fernelmont
# Oostrozebeke
# Heuvelland
# Kortenaken
# Vorselaar
# Langemark-Poelkapelle
# Vielsalm
# Mont-Saint-Guibert
# Wachtebeke
# Estinnes
# Neufchâteau
# Antoing
# Chastre
# Weismes
# Dalhem
# Heers
# Wellen
# Hamois
# Terhulpen
# Zutendaal
# Linter
# Bevekom
# Gesves
# Walhain
# Stavelot
# Beaumont
# Anhée
# Assesse
# Nieuwerkerken
# Chièvres
# Itter
# Hoegaarden
# Hensies
# Quiévrain
# Saint-Georges-sur-Meuse
# Sint-Laureins
# Pittem
# Herne
# Lierde
# Ramillies
# Villers-le-Bouillet
# Kluisbergen
# Moerbeke
# Kaprijke
# Wortegem-Petegem
# Braives
# Maarkedal
# Bekkevoort
# Engis
# Geetbets
# Hastière
# Elzele
# Limburg
# Remicourt
# Etalle
# Lobbes
# Lontzen
# Nandrin
# Lendelede
# Thimister-Clermont
# Pecq
# Drogenbos
# Celles
# Viroinval
# Somme-Leuze
# Vaux-sur-Sûre
# Bütgenbach
# Attert
# Florenville
# Saint-Hubert
# Hotton
# Nassogne
# Incourt
# Büllingen
# Amel
# Léglise
# Marchin
# Bouillon
# Comblain-au-Pont
# Paliseul
# Héron
# Ruiselede
# Momignies
# Gouvy
# Glabbeek
# Libin
# Houffalize
# Chiny
# Havelange
# Rumes
# Honnelles
# Ohey
# Alveringem
# Houyet
# Ferrières
# Cerfontaine
# Sivry-Rance
# Linkebeek
# Clavier
# Gedinne
# Musson
# Lens
# Pepingen
# Baelen
# Tintigny
# Aubel
# Merbes-le-Château
# La Roche-en-Ardenne
# Verlaine
# Modave
# Anthisnes
# Voeren
# Olne
# Froidchapelle
# Burg-Reuland
# Faimes
# Oerle
# Hamoir
# Mont-de-l'Enclus
# Brugelette
# Vleteren
# Bertogne
# Lierneux
# Saint-Léger
# Manhay
# Hélécine
# Geer
# Vloesberg
# Crisnée
# Bièvre
# Lijsem
# Lo-Reninge
# Érezée
# Onhaye
# Burdinne
# Fexhe-le-Haut-Clocher
# Stoumont
# Berloz
# Wellin
# Donceel
# Doische
# Wasseiges
# Tenneville
# Meix-devant-Virton
# Ouffet
# Baarle-Hertog
# Zuienkerke
# Tinlot
# Rendeux
# Vresse-sur-Semois
# Sainte-Ode
# Trois-Ponts
# Tellin
# Fauvillers
# Bever
# Rouvroy
# Spiere-Helkijn
# Horebeke
# Martelange
# Herbeumont
# Daverdisse
# Mesen
# Herstappe

# %%
df_cities['Latitude'] = lat_list
df_cities['Longitude'] = lng_list
df_cities['BoundingBox'] = bb_list
print(df_cities.shape)
df_cities.head()
# Out:
# (581, 11)
#   ID       Name Habitants Index Acreage HabitantsPerSquareKm ProsperityIndex  \
# 0  1  Antwerpen   525.935   443  204,51                2.572            88,2
# 1  2       Gent   262.219   204  156,18                1.679           102,3
# 2  3  Charleroi   202.267   370  102,08                1.982            73,0
# 3  4       Luik   197.327   219   69,39                2.844            81,4
# 4  5    Brussel   181.726   140   32,61                5.573            70,0
#
#           Province    Latitude  Longitude  \
# 0        Antwerpen  51.2211097  4.3997081
# 1  Oost-Vlaanderen  51.0538286  3.7250121
# 2       Henegouwen  50.4120332  4.4436244
# 3             Luik  50.6451381  5.5734203
# 4          Brussel  50.8465573   4.351697
#
#                                       BoundingBox
# 0  [51.1432868, 51.3776412, 4.2175769, 4.4979684]
# 1    [50.9795422, 51.187946, 3.5797616, 3.849325]
# 2  [50.3527894, 50.4925149, 4.3474458, 4.5075571]
# 3   [50.5610182, 50.6881981, 5.5233883, 5.675257]
# 4    [50.6865573, 51.0065573, 4.191697, 4.511697]

# %%
df_cities.to_csv('cities_dataset.csv',index=False)

# %% [markdown]
# # Tot hier

# %% [markdown]
# nis_data = 'NISpostalcodes.txt'
# #pandas.read_csv(nis_data, sep='\t', lineterminator='\r')
# df = pd.read_csv(nis_data, sep='\t', header=None, lineterminator='\r')
# df.columns = ['Postal','NIS5','Name']
# df.head()

# %% [markdown]
# print(df_cities.shape)
# df_cities

# %% [markdown]
# merged_df = pd.merge(df_cities,df,how='outer')
# print(merged_df.shape)
# merged_df

# %% [markdown]
# cities_set = set(df_cities['Name'])
# merged_set = set(merged_df['Name'])
# diff = cities_set - merged_set
# diff

# %% [markdown]
# req = requests.get(cities_page)
# print(req.encoding)
# req.status_code

# %% [markdown]
# import requests
#
# url_pc = 'https://basisregisters.vlaanderen.be/api/v2/adresmatch?Gemeentenaam=Lokeren'
#
# resp = requests.get(url_pc)
# print(resp)

# %%
# KBO-codes-identificatie.xls
NIS_codes_df = pd.read_excel('KBO-codes-identificatie.xls', sheet_name='NIS codes' , index_col=0, skiprows=[0])
NIS_codes_df.columns = ['Frans','Nederlands','Duits','Begin','Einde']
NIS_codes_df.head(10)
# Out:
#           Frans         Nederlands Duits       Begin       Einde
# CODE
# 12041       NaN  Puurs-Sint-Amands   NaN  01.01.2019  31.12.9999
# 44083       NaN             Deinze   NaN  01.01.2019  31.12.9999
# 44084       NaN             Aalter   NaN  01.01.2019  31.12.9999
# 44085       NaN           Lievegem   NaN  01.01.2019  31.12.9999
# 45068       NaN            Kruisem   NaN  01.01.2019  31.12.9999
# 51067   Enghien            Edingen   NaN  01.01.2019  31.12.9999
# 51068     Silly           Opzullik   NaN  01.01.2019  31.12.9999
# 51069  Lessines             Lessen   NaN  01.01.2019  31.12.9999
# 55085   Seneffe                  -     -  01.01.2019  31.12.9999
# 55086    Manage                  -     -  01.01.2019  31.12.9999

# %%
NIS_codes_df['Frans']
# Out:
# CODE
# 12041                              NaN
# 44083                              NaN
# 44084                              NaN
# 44085                              NaN
# 45068                              NaN
# 51067                          Enghien
# 51068                            Silly
# 51069                         Lessines
# 55085                          Seneffe
# 55086                           Manage
# 57096                         Mouscron
# 57097                 Comines-Warneton
# 58001                      La Louvière
# 58002                           Binche
# 58003                         Estinnes
# 58004                       Morlanwelz
# 72042                                -
# 72043                              NaN
# 10000                        Pr.Anvers
# 11001                                -
# 11002                           Anvers
# 11003                                -
# 11004                                -
# 11005                                -
# 11006                                -
# 11007                                -
# 11008                                -
# 11009                                -
# 11010                                -
# 11011                                -
#                      ...
# 93069                         Serville
# 93070                       Silenrieux
# 93071                           Somzée
# 93072                           Soulme
# 93073                           Soumoy
# 93074                            Stave
# 93075                           Surice
# 93076                        Tarcienne
# 93077                   Thy-le-Bauduin
# 93078                   Thy-le-Château
# 93079                         Treignes
# 93080                        Vaucelles
# 93081               Vierves-sur-Viroin
# 93082             Villers-Deux-Eglises
# 93083                 Villers-en-Fagne
# 93084                Villers-le-Gambon
# 93085                          Vodecée
# 93086                          Vodelée
# 93087                          Vogenée
# 93088                         Walcourt
# 93089                     Yves-Gomezée
# 93090                        Viroinval
# 98002     Ministère des Communications
# 98005    Ministère Affaires Etrangères
# 98006    Conseil de guerre en campagne
# 98007                   Cour militaire
# 99990                        Décédé(e)
# 99991                Radié(e) d'office
# 99994                   Dossier annulé
# 99995        Dispensé(e) d'inscription
# Name: Frans, Length: 2861, dtype: object

# %%
NIS_codes_df['Name'] = np.where(NIS_codes_df['Nederlands'] == '-', NIS_codes_df['Frans'], NIS_codes_df['Nederlands'])
NIS_codes_df
# Out:
#                                Frans                         Nederlands  \
# CODE
# 12041                            NaN                  Puurs-Sint-Amands
# 44083                            NaN                             Deinze
# 44084                            NaN                             Aalter
# 44085                            NaN                           Lievegem
# 45068                            NaN                            Kruisem
# 51067                        Enghien                            Edingen
# 51068                          Silly                           Opzullik
# 51069                       Lessines                             Lessen
# 55085                        Seneffe                                  -
# 55086                         Manage                                  -
# 57096                       Mouscron                          Moeskroen
# 57097               Comines-Warneton                      Komen-Waasten
# 58001                    La Louvière                                  -
# 58002                         Binche                                  -
# 58003                       Estinnes                                  -
# 58004                     Morlanwelz                                  -
# 72042                              -                         Oudsbergen
# 72043                            NaN                               Pelt
# 10000                      Pr.Anvers                       Pr.Antwerpen
# 11001                              -                         Aartselaar
# 11002                         Anvers                          Antwerpen
# 11003                              -                     Berchem (Ant.)
# 11004                              -                           Boechout
# 11005                              -                               Boom
# 11006                              -                         Borgerhout
# 11007                              -                           Borsbeek
# 11008                              -                         Brasschaat
# 11009                              -                             Brecht
# 11010                              -                           Broechem
# 11011                              -                             Burcht
# ...                              ...                                ...
# 93069                       Serville                                  -
# 93070                     Silenrieux                                  -
# 93071                         Somzée                                  -
# 93072                         Soulme                                  -
# 93073                         Soumoy                                  -
# 93074                          Stave                                  -
# 93075                         Surice                                  -
# 93076                      Tarcienne                                  -
# 93077                 Thy-le-Bauduin                                  -
# 93078                 Thy-le-Château                                  -
# 93079                       Treignes                                  -
# 93080                      Vaucelles                                  -
# 93081             Vierves-sur-Viroin                                  -
# 93082           Villers-Deux-Eglises                                  -
# 93083               Villers-en-Fagne                                  -
# 93084              Villers-le-Gambon                                  -
# 93085                        Vodecée                                  -
# 93086                        Vodelée                                  -
# 93087                        Vogenée                                  -
# 93088                       Walcourt                                  -
# 93089                   Yves-Gomezée                                  -
# 93090                      Viroinval                                  -
# 98002   Ministère des Communications       Ministerie van Verkeerswegen
# 98005  Ministère Affaires Etrangères  Ministerie van Buitenlandse Zaken
# 98006  Conseil de guerre en campagne                Krijgsraad te velde
# 98007                 Cour militaire               Militair Gerechtshof
# 99990                      Décédé(e)                          Overleden
# 99991              Radié(e) d'office            Afvoering van ambtswege
# 99994                 Dossier annulé                Geannuleerd dossier
# 99995      Dispensé(e) d'inscription       Vrijgesteld van inschrijving
#
#                                    Duits       Begin       Einde  \
# CODE
# 12041                                NaN  01.01.2019  31.12.9999
# 44083                                NaN  01.01.2019  31.12.9999
# 44084                                NaN  01.01.2019  31.12.9999
# 44085                                NaN  01.01.2019  31.12.9999
# 45068                                NaN  01.01.2019  31.12.9999
# 51067                                NaN  01.01.2019  31.12.9999
# 51068                                NaN  01.01.2019  31.12.9999
# 51069                                NaN  01.01.2019  31.12.9999
# 55085                                  -  01.01.2019  31.12.9999
# 55086                                  -  01.01.2019  31.12.9999
# 57096                                NaN  01.01.2019  31.12.9999
# 57097                                NaN  01.01.2019  31.12.9999
# 58001                                  -  01.01.2019  31.12.9999
# 58002                                  -  01.01.2019  31.12.9999
# 58003                                  -  01.01.2019  31.12.9999
# 58004                                  -  01.01.2019  31.12.9999
# 72042                                  -  01.01.2019  31.12.9999
# 72043                                NaN  01.01.2019  31.12.9999
# 10000                       Pr.Antwerpen  01.01.0001  31.12.9999
# 11001                                  -  01.01.0001  31.12.9999
# 11002                          Antwerpen  01.01.0001  31.12.9999
# 11003                                  -  01.01.0001  01.01.1983
# 11004                                  -  01.01.0001  31.12.9999
# 11005                                  -  01.01.0001  31.12.9999
# 11006                                  -  01.01.0001  01.01.1983
# 11007                                  -  01.01.0001  31.12.9999
# 11008                                  -  01.01.0001  31.12.9999
# 11009                                  -  01.01.0001  31.12.9999
# 11010                                  -  01.01.0001  03.01.1977
# 11011                                  -  01.01.0001  03.01.1977
# ...                                  ...         ...         ...
# 93069                                  -  01.01.0001  01.01.1977
# 93070                                  -  01.01.0001  02.01.1977
# 93071                                  -  01.01.0001  02.01.1977
# 93072                                  -  01.01.0001  02.01.1977
# 93073                                  -  01.01.0001  01.01.1977
# 93074                                  -  01.01.0001  02.01.1977
# 93075                                  -  01.01.0001  02.01.1977
# 93076                                  -  01.01.0001  02.01.1977
# 93077                                  -  01.01.0001  02.01.1977
# 93078                                  -  01.01.0001  02.01.1977
# 93079                                  -  01.01.0001  02.01.1977
# 93080                                  -  01.01.0001  02.01.1977
# 93081                                  -  01.01.0001  02.01.1977
# 93082                                  -  01.01.0001  01.01.1977
# 93083                                  -  01.01.0001  02.01.1977
# 93084                                  -  01.01.0001  02.01.1977
# 93085                                  -  01.01.0001  02.01.1977
# 93086                                  -  01.01.0001  02.01.1977
# 93087                                  -  01.01.0001  02.01.1977
# 93088                                  -  01.01.0001  31.12.9999
# 93089                                  -  01.01.0001  02.01.1977
# 93090                                  -  02.01.1977  31.12.9999
# 98002                Verkehrsministerium  01.01.0001  31.12.9999
# 98005                  Aussenministerium  01.01.0001  31.12.9999
# 98006             Kriegsgericht im Felde  01.01.0001  31.12.9999
# 98007                 Militärgerichtshof  01.01.0001  31.12.9999
# 99990                          Gestorben  01.01.0001  31.12.9999
# 99991           Streichung von Amtswegen  01.01.0001  31.12.9999
# 99994                    Akte aufgehoben  01.01.0001  31.12.9999
# 99995  Von der Einschreibung dispensiert  01.01.0001  31.12.9999
#
#                                     Name
# CODE
# 12041                  Puurs-Sint-Amands
# 44083                             Deinze
# 44084                             Aalter
# 44085                           Lievegem
# 45068                            Kruisem
# 51067                            Edingen
# 51068                           Opzullik
# 51069                             Lessen
# 55085                            Seneffe
# 55086                             Manage
# 57096                          Moeskroen
# 57097                      Komen-Waasten
# 58001                        La Louvière
# 58002                             Binche
# 58003                           Estinnes
# 58004                         Morlanwelz
# 72042                         Oudsbergen
# 72043                               Pelt
# 10000                       Pr.Antwerpen
# 11001                         Aartselaar
# 11002                          Antwerpen
# 11003                     Berchem (Ant.)
# 11004                           Boechout
# 11005                               Boom
# 11006                         Borgerhout
# 11007                           Borsbeek
# 11008                         Brasschaat
# 11009                             Brecht
# 11010                           Broechem
# 11011                             Burcht
# ...                                  ...
# 93069                           Serville
# 93070                         Silenrieux
# 93071                             Somzée
# 93072                             Soulme
# 93073                             Soumoy
# 93074                              Stave
# 93075                             Surice
# 93076                          Tarcienne
# 93077                     Thy-le-Bauduin
# 93078                     Thy-le-Château
# 93079                           Treignes
# 93080                          Vaucelles
# 93081                 Vierves-sur-Viroin
# 93082               Villers-Deux-Eglises
# 93083                   Villers-en-Fagne
# 93084                  Villers-le-Gambon
# 93085                            Vodecée
# 93086                            Vodelée
# 93087                            Vogenée
# 93088                           Walcourt
# 93089                       Yves-Gomezée
# 93090                          Viroinval
# 98002       Ministerie van Verkeerswegen
# 98005  Ministerie van Buitenlandse Zaken
# 98006                Krijgsraad te velde
# 98007               Militair Gerechtshof
# 99990                          Overleden
# 99991            Afvoering van ambtswege
# 99994                Geannuleerd dossier
# 99995       Vrijgesteld van inschrijving
#
# [2861 rows x 6 columns]

# %% [markdown]
# NIS_codes_df.loc[NIS_codes_df['Nederlands']=='-', 'Nederlands'] = NIS_codes_df['Frans']
# NIS_codes_df.reset_index(inplace=True)
# NIS_codes_df

# %% [markdown]
# def updateName(row):
#     #print(type(row))
#     #print(row.index)
#     #print(row[0])
#     #print(row[1])
#
#     if(row[1] == '-'):
#         row[1] = row[0]
#
# df_new = NIS_codes_df.apply(lambda row: updateName(row), axis = 1)

# %% [markdown]
# #df_new

# %%
print(df_cities.shape)
df_cities
# Out:
# (581, 11)
#       ID                    Name Habitants  Index Acreage  \
# 0      1               Antwerpen   525.935    443  204,51
# 1      2                    Gent   262.219    204  156,18
# 2      3               Charleroi   202.267    370  102,08
# 3      4                    Luik   197.327    219   69,39
# 4      5                 Brussel   181.726    140   32,61
# 5      6              Schaarbeek   133.309  2.146    8,14
# 6      7              Anderlecht   119.714  2.007   17,74
# 7      8                  Brugge   118.325    194  138,40
# 8      9                   Namen   110.779    260  175,69
# 9     10                  Leuven   101.624    288   56,63
# 10    11     Sint-Jans-Molenbeek    97.462    808    5,89
# 11    12                  Bergen    95.613    183  146,53
# 12    13                  Elsene    86.876    610    6,34
# 13    14                Mechelen    86.616    235   65,19
# 14    15                   Aalst    86.445    263   78,12
# 15    16                   Ukkel    83.024  1.303   22,91
# 16    17             La Louvière    80.757    483   64,24
# 17    18                 Hasselt    78.296    514  102,24
# 18    19            Sint-Niklaas    77.769    259   83,80
# 19    20                Kortrijk    76.735    218   80,02
# 20    21                Oostende    71.494    446   37,72
# 21    22                 Doornik    69.370    106  213,75
# 22    23                    Genk    66.227  3.728   87,85
# 23    24                 Seraing    64.259    373   35,34
# 24    25               Roeselare    62.954    292   59,79
# 25    26               Moeskroen    58.474    426   40,08
# 26    27  Sint-Lambrechts-Woluwe    56.660  4.794    7,22
# 27    28                   Vorst    56.289  4.251    6,25
# 28    29                Verviers    55.207    160   33,07
# 29    30                   Jette    52.536  2.652    5,04
# ..   ...                     ...       ...    ...     ...
# 551  552                  Onhaye     3.241     93   65,53
# 552  553                Burdinne     3.238    101   32,57
# 553  554   Fexhe-le-Haut-Clocher     3.233    229   19,25
# 554  555                Stoumont     3.167     81  108,45
# 555  556                  Berloz     3.132    202   14,49
# 556  557                  Wellin     3.093    151   67,52
# 557  558                 Donceel     3.060    166   23,31
# 558  559                 Doische     2.997    100   84,02
# 559  560               Wasseiges     2.937     99   24,45
# 560  561              Tenneville     2.832    119   91,81
# 561  562      Meix-devant-Virton     2.809     77   54,20
# 562  563                  Ouffet     2.776    160   40,22
# 563  564           Baarle-Hertog     2.760    274    7,48
# 564  565              Zuienkerke     2.721    113   48,86
# 565  566                  Tinlot     2.706    156   37,12
# 566  567                 Rendeux     2.637     79   68,83
# 567  568       Vresse-sur-Semois     2.615     56  101,04
# 568  569              Sainte-Ode     2.555    121   97,87
# 569  570             Trois-Ponts     2.553    127   68,90
# 570  571                  Tellin     2.432    150   56,64
# 571  572              Fauvillers     2.281     88   74,11
# 572  573                   Bever     2.159     63   19,78
# 573  574                 Rouvroy     2.107    110   27,68
# 574  575          Spiere-Helkijn     2.049     94   10,78
# 575  576                Horebeke     2.036     72   11,20
# 576  577              Martelange     1.876    168   29,67
# 577  578              Herbeumont     1.624     67   58,81
# 578  579              Daverdisse     1.395     92   56,40
# 579  580                   Mesen     1.065     75    3,58
# 580  581               Herstappe        83     61    1,35
#
#     HabitantsPerSquareKm ProsperityIndex         Province    Latitude  \
# 0                  2.572            88,2        Antwerpen  51.2211097
# 1                  1.679           102,3  Oost-Vlaanderen  51.0538286
# 2                  1.982            73,0       Henegouwen  50.4120332
# 3                  2.844            81,4             Luik  50.6451381
# 4                  5.573            70,0          Brussel  50.8465573
# 5                 16.377            65,4          Brussel  50.8676041
# 6                  6.747            63,8          Brussel  50.8390983
# 7                    855           111,7  West-Vlaanderen  51.2085526
# 8                    631            99,9            Namen  50.4665284
# 9                  1.794           113,6   Vlaams-Brabant   50.879202
# 10                16.542            57,1          Brussel  50.8545959
# 11                   653            88,1       Henegouwen  50.4549568
# 12                13.693            89,7          Brussel  50.8331141
# 13                 1.329           104,8        Antwerpen  51.0281381
# 14                 1.107           107,6  Oost-Vlaanderen  50.9383226
# 15                 3.624           112,9          Brussel  50.8035441
# 16                 1.257            79,8       Henegouwen   50.479487
# 17                   766           113,2          Limburg  50.9303735
# 18                   927            99,3  Oost-Vlaanderen  51.1646685
# 19                   959           104,5  West-Vlaanderen  50.8276429
# 20                 1.895           100,3  West-Vlaanderen  51.2258565
# 21                   325            94,8       Henegouwen    50.60566
# 22                   754            89,5          Limburg  50.9654864
# 23                 1.819            77,5             Luik  50.6152381
# 24                 1.053           102,1  West-Vlaanderen  50.9444948
# 25                 1.459            84,3       Henegouwen  50.7433351
# 26                 7.842            94,9          Brussel  50.8430448
# 27                 9.009            81,4          Brussel  50.8091426
# 28                 1.669            77,9             Luik  50.5932274
# 29                10.417            82,4          Brussel  50.8759585
# ..                   ...             ...              ...         ...
# 551                   49            93,6            Namen  50.2435657
# 552                   99           109,5             Luik  50.5812607
# 553                  168           111,8             Luik  50.6660818
# 554                   29           103,7             Luik  50.4069504
# 555                  216           108,8             Luik  50.6977331
# 556                   46            90,0        Luxemburg  50.0822967
# 557                  131           117,9             Luik  50.6478971
# 558                   36            85,9            Namen  50.1357152
# 559                  120            98,7             Luik  50.6210088
# 560                   31            97,8        Luxemburg   50.091248
# 561                   52            95,4        Luxemburg  49.6055933
# 562                   69            98,3             Luik  50.4377341
# 563                  369            87,9        Antwerpen  51.4383589
# 564                   56           113,0  West-Vlaanderen  51.2685834
# 565                   73           110,1             Luik  50.4777419
# 566                   38            90,3        Luxemburg  50.2330466
# 567                   26            85,0            Namen  49.8729769
# 568                   26            88,1        Luxemburg  50.0362888
# 569                   37            93,4             Luik  50.3726812
# 570                   43            93,1        Luxemburg   50.081019
# 571                   31            98,6        Luxemburg  49.8509306
# 572                  109           114,5   Vlaams-Brabant  50.7164481
# 573                   76            94,4        Luxemburg   49.539075
# 574                  190            94,9  West-Vlaanderen  50.7279919
# 575                  182           118,8  Oost-Vlaanderen  50.8348628
# 576                   63            96,2        Luxemburg  49.8313323
# 577                   28            90,5        Luxemburg  49.7815364
# 578                   25            83,4        Luxemburg  50.0217646
# 579                  298            76,2  West-Vlaanderen   50.765419
# 580                   61           108,6          Limburg  50.7273829
#
#             Longitude                                     BoundingBox
# 0           4.3997081  [51.1432868, 51.3776412, 4.2175769, 4.4979684]
# 1           3.7250121    [50.9795422, 51.187946, 3.5797616, 3.849325]
# 2           4.4436244  [50.3527894, 50.4925149, 4.3474458, 4.5075571]
# 3           5.5734203   [50.5610182, 50.6881981, 5.5233883, 5.675257]
# 4            4.351697    [50.6865573, 51.0065573, 4.191697, 4.511697]
# 5           4.3737121  [50.8434069, 50.8811977, 4.3571322, 4.4130849]
# 6           4.3296526   [50.8070598, 50.850549, 4.2437658, 4.3402385]
# 7            3.226772    [51.1581918, 51.363347, 3.1341802, 3.309804]
# 8           4.8661892   [50.3872825, 50.5313007, 4.723053, 4.9841776]
# 9           4.7011675   [50.8242096, 50.9440707, 4.640295, 4.7705305]
# 10           4.338636   [50.844035, 50.8714317, 4.2831135, 4.3487272]
# 11           3.951958   [50.3777531, 50.5138107, 3.8547797, 4.085104]
# 12          4.3668279  [50.8009321, 50.8406267, 4.3479344, 4.4034045]
# 13          4.4803453   [50.9909709, 51.0785768, 4.3700927, 4.549039]
# 14          4.0392147  [50.8993828, 50.9948309, 3.9824469, 4.1641424]
# 15          4.3338445   [50.763682, 50.8169786, 4.3110983, 4.4128924]
# 16          4.1852682  [50.4332671, 50.5249551, 4.0699218, 4.2299745]
# 17          5.3378043   [50.8675417, 50.981282, 5.2121524, 5.4149391]
# 18          4.1395124  [51.1296079, 51.2078094, 3.9853092, 4.2216963]
# 19          3.2659884   [50.7310386, 50.874934, 3.2007586, 3.3588007]
# 20           2.919496  [51.1846337, 51.2455721, 2.8386276, 3.0035408]
# 21          3.3878259  [50.5523575, 50.6887918, 3.2440216, 3.5769352]
# 22          5.5001456   [50.9130492, 51.020766, 5.3843163, 5.5951688]
# 23          5.5089437  [50.5472961, 50.6286135, 5.4698932, 5.5660933]
# 24           3.124765  [50.8870139, 50.9940257, 3.0619143, 3.1784858]
# 25          3.2139093  [50.7099086, 50.7658775, 3.1783878, 3.3292102]
# 26          4.4256732   [50.8337623, 50.8630337, 4.3999896, 4.461777]
# 27          4.3177512   [50.7975919, 50.8308078, 4.3019949, 4.353607]
# 28          5.8638544  [50.5492321, 50.6258273, 5.8130414, 5.9256531]
# 29          4.3245702   [50.864506, 50.8941515, 4.2937557, 4.3406693]
# ..                ...                                             ...
# 551          4.840864   [50.214696, 50.3111173, 4.7360267, 4.8937537]
# 552          5.072436    [50.5552451, 50.608095, 5.027859, 5.1669208]
# 553         5.3985197   [50.6392849, 50.6918017, 5.3482158, 5.440566]
# 554           5.80836    [50.35625, 50.4642046, 5.6700851, 5.9309101]
# 555         5.2146261   [50.6835696, 50.723727, 5.1650784, 5.2353501]
# 556         5.1146708    [50.0159061, 50.1230465, 5.011381, 5.178179]
# 557         5.3199408  [50.6252332, 50.6752185, 5.2809354, 5.3764618]
# 558         4.7458219     [50.09183, 50.2099841, 4.583007, 4.7995471]
# 559          5.006907  [50.5879719, 50.6465153, 4.9794305, 5.0618115]
# 560         5.5242133    [50.0477579, 50.1517225, 5.389167, 5.597304]
# 561         5.4816156  [49.5637153, 49.6397398, 5.3752213, 5.5331264]
# 562         5.4653273    [50.407621, 50.4826969, 5.383756, 5.5368484]
# 563         4.9316995      [51.392824, 51.45563, 4.8357449, 4.952758]
# 564  3.15674060943262      [51.243806, 51.29076, 3.1160425, 3.193541]
# 565         5.3786954  [50.4466996, 50.5062878, 5.3076371, 5.4454947]
# 566         5.5043243  [50.1638022, 50.2651698, 5.4421258, 5.6135255]
# 567         4.9340633  [49.7855452, 49.9309164, 4.8475351, 4.9908124]
# 568         5.5245094  [49.9552613, 50.0775516, 5.4148743, 5.6270529]
# 569         5.8702957  [50.3197785, 50.3912922, 5.7597006, 6.0020397]
# 570          5.216837  [50.0261117, 50.1102221, 5.1524704, 5.3170064]
# 571          5.665031  [49.8200397, 49.9424849, 5.6143425, 5.7840328]
# 572          3.943147    [50.6889705, 50.7330106, 3.88932, 3.9741728]
# 573           5.48971  [49.4969821, 49.5749892, 5.4414056, 5.5333188]
# 574         3.3667739  [50.7096189, 50.7481815, 3.3237599, 3.4044791]
# 575         3.6920346   [50.7983998, 50.8622645, 3.672245, 3.7160527]
# 576         5.7376366   [49.7719946, 49.8577727, 5.6845055, 5.758543]
# 577         5.2377736  [49.7593794, 49.8322323, 5.2151581, 5.3963205]
# 578         5.1184644  [49.9612874, 50.0452849, 4.9729894, 5.1520514]
# 579         2.8984493  [50.7527296, 50.7670386, 2.8695657, 2.9224658]
# 580         5.4260923   [50.718121, 50.7354411, 5.4155455, 5.4361065]
#
# [581 rows x 11 columns]

# %%
NIS_codes_df
# Out:
#                                Frans                         Nederlands  \
# CODE
# 12041                            NaN                  Puurs-Sint-Amands
# 44083                            NaN                             Deinze
# 44084                            NaN                             Aalter
# 44085                            NaN                           Lievegem
# 45068                            NaN                            Kruisem
# 51067                        Enghien                            Edingen
# 51068                          Silly                           Opzullik
# 51069                       Lessines                             Lessen
# 55085                        Seneffe                                  -
# 55086                         Manage                                  -
# 57096                       Mouscron                          Moeskroen
# 57097               Comines-Warneton                      Komen-Waasten
# 58001                    La Louvière                                  -
# 58002                         Binche                                  -
# 58003                       Estinnes                                  -
# 58004                     Morlanwelz                                  -
# 72042                              -                         Oudsbergen
# 72043                            NaN                               Pelt
# 10000                      Pr.Anvers                       Pr.Antwerpen
# 11001                              -                         Aartselaar
# 11002                         Anvers                          Antwerpen
# 11003                              -                     Berchem (Ant.)
# 11004                              -                           Boechout
# 11005                              -                               Boom
# 11006                              -                         Borgerhout
# 11007                              -                           Borsbeek
# 11008                              -                         Brasschaat
# 11009                              -                             Brecht
# 11010                              -                           Broechem
# 11011                              -                             Burcht
# ...                              ...                                ...
# 93069                       Serville                                  -
# 93070                     Silenrieux                                  -
# 93071                         Somzée                                  -
# 93072                         Soulme                                  -
# 93073                         Soumoy                                  -
# 93074                          Stave                                  -
# 93075                         Surice                                  -
# 93076                      Tarcienne                                  -
# 93077                 Thy-le-Bauduin                                  -
# 93078                 Thy-le-Château                                  -
# 93079                       Treignes                                  -
# 93080                      Vaucelles                                  -
# 93081             Vierves-sur-Viroin                                  -
# 93082           Villers-Deux-Eglises                                  -
# 93083               Villers-en-Fagne                                  -
# 93084              Villers-le-Gambon                                  -
# 93085                        Vodecée                                  -
# 93086                        Vodelée                                  -
# 93087                        Vogenée                                  -
# 93088                       Walcourt                                  -
# 93089                   Yves-Gomezée                                  -
# 93090                      Viroinval                                  -
# 98002   Ministère des Communications       Ministerie van Verkeerswegen
# 98005  Ministère Affaires Etrangères  Ministerie van Buitenlandse Zaken
# 98006  Conseil de guerre en campagne                Krijgsraad te velde
# 98007                 Cour militaire               Militair Gerechtshof
# 99990                      Décédé(e)                          Overleden
# 99991              Radié(e) d'office            Afvoering van ambtswege
# 99994                 Dossier annulé                Geannuleerd dossier
# 99995      Dispensé(e) d'inscription       Vrijgesteld van inschrijving
#
#                                    Duits       Begin       Einde  \
# CODE
# 12041                                NaN  01.01.2019  31.12.9999
# 44083                                NaN  01.01.2019  31.12.9999
# 44084                                NaN  01.01.2019  31.12.9999
# 44085                                NaN  01.01.2019  31.12.9999
# 45068                                NaN  01.01.2019  31.12.9999
# 51067                                NaN  01.01.2019  31.12.9999
# 51068                                NaN  01.01.2019  31.12.9999
# 51069                                NaN  01.01.2019  31.12.9999
# 55085                                  -  01.01.2019  31.12.9999
# 55086                                  -  01.01.2019  31.12.9999
# 57096                                NaN  01.01.2019  31.12.9999
# 57097                                NaN  01.01.2019  31.12.9999
# 58001                                  -  01.01.2019  31.12.9999
# 58002                                  -  01.01.2019  31.12.9999
# 58003                                  -  01.01.2019  31.12.9999
# 58004                                  -  01.01.2019  31.12.9999
# 72042                                  -  01.01.2019  31.12.9999
# 72043                                NaN  01.01.2019  31.12.9999
# 10000                       Pr.Antwerpen  01.01.0001  31.12.9999
# 11001                                  -  01.01.0001  31.12.9999
# 11002                          Antwerpen  01.01.0001  31.12.9999
# 11003                                  -  01.01.0001  01.01.1983
# 11004                                  -  01.01.0001  31.12.9999
# 11005                                  -  01.01.0001  31.12.9999
# 11006                                  -  01.01.0001  01.01.1983
# 11007                                  -  01.01.0001  31.12.9999
# 11008                                  -  01.01.0001  31.12.9999
# 11009                                  -  01.01.0001  31.12.9999
# 11010                                  -  01.01.0001  03.01.1977
# 11011                                  -  01.01.0001  03.01.1977
# ...                                  ...         ...         ...
# 93069                                  -  01.01.0001  01.01.1977
# 93070                                  -  01.01.0001  02.01.1977
# 93071                                  -  01.01.0001  02.01.1977
# 93072                                  -  01.01.0001  02.01.1977
# 93073                                  -  01.01.0001  01.01.1977
# 93074                                  -  01.01.0001  02.01.1977
# 93075                                  -  01.01.0001  02.01.1977
# 93076                                  -  01.01.0001  02.01.1977
# 93077                                  -  01.01.0001  02.01.1977
# 93078                                  -  01.01.0001  02.01.1977
# 93079                                  -  01.01.0001  02.01.1977
# 93080                                  -  01.01.0001  02.01.1977
# 93081                                  -  01.01.0001  02.01.1977
# 93082                                  -  01.01.0001  01.01.1977
# 93083                                  -  01.01.0001  02.01.1977
# 93084                                  -  01.01.0001  02.01.1977
# 93085                                  -  01.01.0001  02.01.1977
# 93086                                  -  01.01.0001  02.01.1977
# 93087                                  -  01.01.0001  02.01.1977
# 93088                                  -  01.01.0001  31.12.9999
# 93089                                  -  01.01.0001  02.01.1977
# 93090                                  -  02.01.1977  31.12.9999
# 98002                Verkehrsministerium  01.01.0001  31.12.9999
# 98005                  Aussenministerium  01.01.0001  31.12.9999
# 98006             Kriegsgericht im Felde  01.01.0001  31.12.9999
# 98007                 Militärgerichtshof  01.01.0001  31.12.9999
# 99990                          Gestorben  01.01.0001  31.12.9999
# 99991           Streichung von Amtswegen  01.01.0001  31.12.9999
# 99994                    Akte aufgehoben  01.01.0001  31.12.9999
# 99995  Von der Einschreibung dispensiert  01.01.0001  31.12.9999
#
#                                     Name
# CODE
# 12041                  Puurs-Sint-Amands
# 44083                             Deinze
# 44084                             Aalter
# 44085                           Lievegem
# 45068                            Kruisem
# 51067                            Edingen
# 51068                           Opzullik
# 51069                             Lessen
# 55085                            Seneffe
# 55086                             Manage
# 57096                          Moeskroen
# 57097                      Komen-Waasten
# 58001                        La Louvière
# 58002                             Binche
# 58003                           Estinnes
# 58004                         Morlanwelz
# 72042                         Oudsbergen
# 72043                               Pelt
# 10000                       Pr.Antwerpen
# 11001                         Aartselaar
# 11002                          Antwerpen
# 11003                     Berchem (Ant.)
# 11004                           Boechout
# 11005                               Boom
# 11006                         Borgerhout
# 11007                           Borsbeek
# 11008                         Brasschaat
# 11009                             Brecht
# 11010                           Broechem
# 11011                             Burcht
# ...                                  ...
# 93069                           Serville
# 93070                         Silenrieux
# 93071                             Somzée
# 93072                             Soulme
# 93073                             Soumoy
# 93074                              Stave
# 93075                             Surice
# 93076                          Tarcienne
# 93077                     Thy-le-Bauduin
# 93078                     Thy-le-Château
# 93079                           Treignes
# 93080                          Vaucelles
# 93081                 Vierves-sur-Viroin
# 93082               Villers-Deux-Eglises
# 93083                   Villers-en-Fagne
# 93084                  Villers-le-Gambon
# 93085                            Vodecée
# 93086                            Vodelée
# 93087                            Vogenée
# 93088                           Walcourt
# 93089                       Yves-Gomezée
# 93090                          Viroinval
# 98002       Ministerie van Verkeerswegen
# 98005  Ministerie van Buitenlandse Zaken
# 98006                Krijgsraad te velde
# 98007               Militair Gerechtshof
# 99990                          Overleden
# 99991            Afvoering van ambtswege
# 99994                Geannuleerd dossier
# 99995       Vrijgesteld van inschrijving
#
# [2861 rows x 6 columns]

# %%
df_cities_NIS = df_cities.merge(NIS_codes_df)
df_cities_NIS
# Out:
#       ID                    Name Habitants  Index Acreage  \
# 0      1               Antwerpen   525.935    443  204,51
# 1      2                    Gent   262.219    204  156,18
# 2      3               Charleroi   202.267    370  102,08
# 3      4                    Luik   197.327    219   69,39
# 4      5                 Brussel   181.726    140   32,61
# 5      6              Schaarbeek   133.309  2.146    8,14
# 6      7              Anderlecht   119.714  2.007   17,74
# 7      8                  Brugge   118.325    194  138,40
# 8      9                   Namen   110.779    260  175,69
# 9     10                  Leuven   101.624    288   56,63
# 10    11     Sint-Jans-Molenbeek    97.462    808    5,89
# 11    12                  Bergen    95.613    183  146,53
# 12    13                  Elsene    86.876    610    6,34
# 13    14                Mechelen    86.616    235   65,19
# 14    15                   Aalst    86.445    263   78,12
# 15    16                   Ukkel    83.024  1.303   22,91
# 16    17             La Louvière    80.757    483   64,24
# 17    17             La Louvière    80.757    483   64,24
# 18    18                 Hasselt    78.296    514  102,24
# 19    19            Sint-Niklaas    77.769    259   83,80
# 20    20                Kortrijk    76.735    218   80,02
# 21    21                Oostende    71.494    446   37,72
# 22    22                 Doornik    69.370    106  213,75
# 23    23                    Genk    66.227  3.728   87,85
# 24    24                 Seraing    64.259    373   35,34
# 25    25               Roeselare    62.954    292   59,79
# 26    26               Moeskroen    58.474    426   40,08
# 27    26               Moeskroen    58.474    426   40,08
# 28    27  Sint-Lambrechts-Woluwe    56.660  4.794    7,22
# 29    28                   Vorst    56.289  4.251    6,25
# ..   ...                     ...       ...    ...     ...
# 545  552                  Onhaye     3.241     93   65,53
# 546  553                Burdinne     3.238    101   32,57
# 547  554   Fexhe-le-Haut-Clocher     3.233    229   19,25
# 548  555                Stoumont     3.167     81  108,45
# 549  556                  Berloz     3.132    202   14,49
# 550  557                  Wellin     3.093    151   67,52
# 551  558                 Donceel     3.060    166   23,31
# 552  559                 Doische     2.997    100   84,02
# 553  560               Wasseiges     2.937     99   24,45
# 554  561              Tenneville     2.832    119   91,81
# 555  562      Meix-devant-Virton     2.809     77   54,20
# 556  563                  Ouffet     2.776    160   40,22
# 557  564           Baarle-Hertog     2.760    274    7,48
# 558  565              Zuienkerke     2.721    113   48,86
# 559  566                  Tinlot     2.706    156   37,12
# 560  567                 Rendeux     2.637     79   68,83
# 561  568       Vresse-sur-Semois     2.615     56  101,04
# 562  569              Sainte-Ode     2.555    121   97,87
# 563  570             Trois-Ponts     2.553    127   68,90
# 564  571                  Tellin     2.432    150   56,64
# 565  572              Fauvillers     2.281     88   74,11
# 566  573                   Bever     2.159     63   19,78
# 567  574                 Rouvroy     2.107    110   27,68
# 568  575          Spiere-Helkijn     2.049     94   10,78
# 569  576                Horebeke     2.036     72   11,20
# 570  577              Martelange     1.876    168   29,67
# 571  578              Herbeumont     1.624     67   58,81
# 572  579              Daverdisse     1.395     92   56,40
# 573  580                   Mesen     1.065     75    3,58
# 574  581               Herstappe        83     61    1,35
#
#     HabitantsPerSquareKm ProsperityIndex         Province    Latitude  \
# 0                  2.572            88,2        Antwerpen  51.2211097
# 1                  1.679           102,3  Oost-Vlaanderen  51.0538286
# 2                  1.982            73,0       Henegouwen  50.4120332
# 3                  2.844            81,4             Luik  50.6451381
# 4                  5.573            70,0          Brussel  50.8465573
# 5                 16.377            65,4          Brussel  50.8676041
# 6                  6.747            63,8          Brussel  50.8390983
# 7                    855           111,7  West-Vlaanderen  51.2085526
# 8                    631            99,9            Namen  50.4665284
# 9                  1.794           113,6   Vlaams-Brabant   50.879202
# 10                16.542            57,1          Brussel  50.8545959
# 11                   653            88,1       Henegouwen  50.4549568
# 12                13.693            89,7          Brussel  50.8331141
# 13                 1.329           104,8        Antwerpen  51.0281381
# 14                 1.107           107,6  Oost-Vlaanderen  50.9383226
# 15                 3.624           112,9          Brussel  50.8035441
# 16                 1.257            79,8       Henegouwen   50.479487
# 17                 1.257            79,8       Henegouwen   50.479487
# 18                   766           113,2          Limburg  50.9303735
# 19                   927            99,3  Oost-Vlaanderen  51.1646685
# 20                   959           104,5  West-Vlaanderen  50.8276429
# 21                 1.895           100,3  West-Vlaanderen  51.2258565
# 22                   325            94,8       Henegouwen    50.60566
# 23                   754            89,5          Limburg  50.9654864
# 24                 1.819            77,5             Luik  50.6152381
# 25                 1.053           102,1  West-Vlaanderen  50.9444948
# 26                 1.459            84,3       Henegouwen  50.7433351
# 27                 1.459            84,3       Henegouwen  50.7433351
# 28                 7.842            94,9          Brussel  50.8430448
# 29                 9.009            81,4          Brussel  50.8091426
# ..                   ...             ...              ...         ...
# 545                   49            93,6            Namen  50.2435657
# 546                   99           109,5             Luik  50.5812607
# 547                  168           111,8             Luik  50.6660818
# 548                   29           103,7             Luik  50.4069504
# 549                  216           108,8             Luik  50.6977331
# 550                   46            90,0        Luxemburg  50.0822967
# 551                  131           117,9             Luik  50.6478971
# 552                   36            85,9            Namen  50.1357152
# 553                  120            98,7             Luik  50.6210088
# 554                   31            97,8        Luxemburg   50.091248
# 555                   52            95,4        Luxemburg  49.6055933
# 556                   69            98,3             Luik  50.4377341
# 557                  369            87,9        Antwerpen  51.4383589
# 558                   56           113,0  West-Vlaanderen  51.2685834
# 559                   73           110,1             Luik  50.4777419
# 560                   38            90,3        Luxemburg  50.2330466
# 561                   26            85,0            Namen  49.8729769
# 562                   26            88,1        Luxemburg  50.0362888
# 563                   37            93,4             Luik  50.3726812
# 564                   43            93,1        Luxemburg   50.081019
# 565                   31            98,6        Luxemburg  49.8509306
# 566                  109           114,5   Vlaams-Brabant  50.7164481
# 567                   76            94,4        Luxemburg   49.539075
# 568                  190            94,9  West-Vlaanderen  50.7279919
# 569                  182           118,8  Oost-Vlaanderen  50.8348628
# 570                   63            96,2        Luxemburg  49.8313323
# 571                   28            90,5        Luxemburg  49.7815364
# 572                   25            83,4        Luxemburg  50.0217646
# 573                  298            76,2  West-Vlaanderen   50.765419
# 574                   61           108,6          Limburg  50.7273829
#
#             Longitude                                     BoundingBox  \
# 0           4.3997081  [51.1432868, 51.3776412, 4.2175769, 4.4979684]
# 1           3.7250121    [50.9795422, 51.187946, 3.5797616, 3.849325]
# 2           4.4436244  [50.3527894, 50.4925149, 4.3474458, 4.5075571]
# 3           5.5734203   [50.5610182, 50.6881981, 5.5233883, 5.675257]
# 4            4.351697    [50.6865573, 51.0065573, 4.191697, 4.511697]
# 5           4.3737121  [50.8434069, 50.8811977, 4.3571322, 4.4130849]
# 6           4.3296526   [50.8070598, 50.850549, 4.2437658, 4.3402385]
# 7            3.226772    [51.1581918, 51.363347, 3.1341802, 3.309804]
# 8           4.8661892   [50.3872825, 50.5313007, 4.723053, 4.9841776]
# 9           4.7011675   [50.8242096, 50.9440707, 4.640295, 4.7705305]
# 10           4.338636   [50.844035, 50.8714317, 4.2831135, 4.3487272]
# 11           3.951958   [50.3777531, 50.5138107, 3.8547797, 4.085104]
# 12          4.3668279  [50.8009321, 50.8406267, 4.3479344, 4.4034045]
# 13          4.4803453   [50.9909709, 51.0785768, 4.3700927, 4.549039]
# 14          4.0392147  [50.8993828, 50.9948309, 3.9824469, 4.1641424]
# 15          4.3338445   [50.763682, 50.8169786, 4.3110983, 4.4128924]
# 16          4.1852682  [50.4332671, 50.5249551, 4.0699218, 4.2299745]
# 17          4.1852682  [50.4332671, 50.5249551, 4.0699218, 4.2299745]
# 18          5.3378043   [50.8675417, 50.981282, 5.2121524, 5.4149391]
# 19          4.1395124  [51.1296079, 51.2078094, 3.9853092, 4.2216963]
# 20          3.2659884   [50.7310386, 50.874934, 3.2007586, 3.3588007]
# 21           2.919496  [51.1846337, 51.2455721, 2.8386276, 3.0035408]
# 22          3.3878259  [50.5523575, 50.6887918, 3.2440216, 3.5769352]
# 23          5.5001456   [50.9130492, 51.020766, 5.3843163, 5.5951688]
# 24          5.5089437  [50.5472961, 50.6286135, 5.4698932, 5.5660933]
# 25           3.124765  [50.8870139, 50.9940257, 3.0619143, 3.1784858]
# 26          3.2139093  [50.7099086, 50.7658775, 3.1783878, 3.3292102]
# 27          3.2139093  [50.7099086, 50.7658775, 3.1783878, 3.3292102]
# 28          4.4256732   [50.8337623, 50.8630337, 4.3999896, 4.461777]
# 29          4.3177512   [50.7975919, 50.8308078, 4.3019949, 4.353607]
# ..                ...                                             ...
# 545          4.840864   [50.214696, 50.3111173, 4.7360267, 4.8937537]
# 546          5.072436    [50.5552451, 50.608095, 5.027859, 5.1669208]
# 547         5.3985197   [50.6392849, 50.6918017, 5.3482158, 5.440566]
# 548           5.80836    [50.35625, 50.4642046, 5.6700851, 5.9309101]
# 549         5.2146261   [50.6835696, 50.723727, 5.1650784, 5.2353501]
# 550         5.1146708    [50.0159061, 50.1230465, 5.011381, 5.178179]
# 551         5.3199408  [50.6252332, 50.6752185, 5.2809354, 5.3764618]
# 552         4.7458219     [50.09183, 50.2099841, 4.583007, 4.7995471]
# 553          5.006907  [50.5879719, 50.6465153, 4.9794305, 5.0618115]
# 554         5.5242133    [50.0477579, 50.1517225, 5.389167, 5.597304]
# 555         5.4816156  [49.5637153, 49.6397398, 5.3752213, 5.5331264]
# 556         5.4653273    [50.407621, 50.4826969, 5.383756, 5.5368484]
# 557         4.9316995      [51.392824, 51.45563, 4.8357449, 4.952758]
# 558  3.15674060943262      [51.243806, 51.29076, 3.1160425, 3.193541]
# 559         5.3786954  [50.4466996, 50.5062878, 5.3076371, 5.4454947]
# 560         5.5043243  [50.1638022, 50.2651698, 5.4421258, 5.6135255]
# 561         4.9340633  [49.7855452, 49.9309164, 4.8475351, 4.9908124]
# 562         5.5245094  [49.9552613, 50.0775516, 5.4148743, 5.6270529]
# 563         5.8702957  [50.3197785, 50.3912922, 5.7597006, 6.0020397]
# 564          5.216837  [50.0261117, 50.1102221, 5.1524704, 5.3170064]
# 565          5.665031  [49.8200397, 49.9424849, 5.6143425, 5.7840328]
# 566          3.943147    [50.6889705, 50.7330106, 3.88932, 3.9741728]
# 567           5.48971  [49.4969821, 49.5749892, 5.4414056, 5.5333188]
# 568         3.3667739  [50.7096189, 50.7481815, 3.3237599, 3.4044791]
# 569         3.6920346   [50.7983998, 50.8622645, 3.672245, 3.7160527]
# 570         5.7376366   [49.7719946, 49.8577727, 5.6845055, 5.758543]
# 571         5.2377736  [49.7593794, 49.8322323, 5.2151581, 5.3963205]
# 572         5.1184644  [49.9612874, 50.0452849, 4.9729894, 5.1520514]
# 573         2.8984493  [50.7527296, 50.7670386, 2.8695657, 2.9224658]
# 574         5.4260923   [50.718121, 50.7354411, 5.4155455, 5.4361065]
#
#                      Frans              Nederlands          Duits       Begin  \
# 0                   Anvers               Antwerpen      Antwerpen  01.01.0001
# 1                     Gand                    Gent           Gent  01.01.0001
# 2                Charleroi                       -              -  01.01.0001
# 3                    Liège                    Luik        Lüttich  01.01.0001
# 4                Bruxelles                 Brussel              -  01.01.0001
# 5               Schaerbeek              Schaarbeek              -  01.01.0001
# 6               Anderlecht              Anderlecht              -  01.01.0001
# 7                   Bruges                  Brugge         Brügge  01.01.0001
# 8                    Namur                   Namen              -  01.01.0001
# 9                  Louvain                  Leuven          Löwen  01.01.0001
# 10    Molenbeek-Saint-Jean     Sint-Jans-Molenbeek              -  01.01.0001
# 11                    Mons                  Bergen              -  01.01.0001
# 12                 Ixelles                  Elsene              -  01.01.0001
# 13                 Malines                Mechelen       Mechelen  01.01.0001
# 14                   Alost                   Aalst          Aalst  01.01.0001
# 15                   Uccle                   Ukkel              -  01.01.0001
# 16             La Louvière                       -              -  01.01.2019
# 17             La Louvière                       -              -  01.01.0001
# 18                       -                 Hasselt              -  01.01.0001
# 19    Saint-Nicolas (Waes)            Sint-Niklaas   Sint-Niklaas  01.01.0001
# 20                Courtrai                Kortrijk       Kortrijk  01.01.0001
# 21                 Ostende                Oostende       Oostende  01.01.0001
# 22                 Tournai                 Doornik              -  01.01.0001
# 23                       -                    Genk              -  01.01.0001
# 24                 Seraing                       -              -  01.01.0001
# 25                 Roulers               Roeselare      Roeselare  01.01.0001
# 26                Mouscron               Moeskroen            NaN  01.01.2019
# 27                Mouscron               Moeskroen              -  01.01.0001
# 28    Woluwe-Saint-Lambert  Sint-Lambrechts-Woluwe              -  01.01.0001
# 29                  Forest                   Vorst              -  01.01.0001
# ..                     ...                     ...            ...         ...
# 545                 Onhaye                       -              -  01.01.0001
# 546               Burdinne                       -              -  01.01.0001
# 547  Fexhe-le-Haut-Clocher                       -              -  01.01.0001
# 548               Stoumont                       -              -  01.01.0001
# 549                 Berloz                       -              -  01.01.0001
# 550                 Wellin                       -              -  01.01.0001
# 551                Donceel                       -              -  01.01.0001
# 552                Doische                       -              -  01.01.0001
# 553              Wasseiges                       -              -  01.01.0001
# 554             Tenneville                       -              -  01.01.0001
# 555     Meix-devant-Virton                       -              -  01.01.0001
# 556                 Ouffet                       -              -  01.01.0001
# 557             Baerle-Duc           Baarle-Hertog  Baarle-Hertog  01.01.0001
# 558                      -              Zuienkerke              -  01.01.0001
# 559                 Tinlot                       -              -  02.01.1977
# 560                Rendeux                       -              -  01.01.0001
# 561      Vresse-sur-Semois                       -              -  01.02.1977
# 562             Sainte-Ode                       -              -  03.01.1977
# 563            Trois-Ponts                       -              -  01.01.1971
# 564                 Tellin                       -              -  01.01.0001
# 565             Fauvillers                       -              -  01.01.0001
# 566                Biévène                   Bever              -  01.01.0001
# 567                Rouvroy                       -              -  03.01.1977
# 568      Espierres-Helchin          Spiere-Helkijn              -  03.01.1977
# 569                      -                Horebeke              -  01.01.1977
# 570             Martelange                       -              -  01.01.0001
# 571             Herbeumont                       -              -  01.01.0001
# 572             Daverdisse                       -              -  01.01.0001
# 573               Messines                   Mesen              -  01.01.0001
# 574                      -               Herstappe              -  01.01.0001
#
#           Einde
# 0    31.12.9999
# 1    31.12.9999
# 2    31.12.9999
# 3    31.12.9999
# 4    31.12.9999
# 5    31.12.9999
# 6    31.12.9999
# 7    31.12.9999
# 8    31.12.9999
# 9    31.12.9999
# 10   31.12.9999
# 11   31.12.9999
# 12   31.12.9999
# 13   31.12.9999
# 14   31.12.9999
# 15   31.12.9999
# 16   31.12.9999
# 17   31.12.2018
# 18   31.12.9999
# 19   31.12.9999
# 20   31.12.9999
# 21   31.12.9999
# 22   31.12.9999
# 23   31.12.9999
# 24   31.12.9999
# 25   31.12.9999
# 26   31.12.9999
# 27   31.12.2018
# 28   31.12.9999
# 29   31.12.9999
# ..          ...
# 545  31.12.9999
# 546  31.12.9999
# 547  31.12.9999
# 548  31.12.9999
# 549  31.12.9999
# 550  31.12.9999
# 551  31.12.9999
# 552  31.12.9999
# 553  31.12.9999
# 554  31.12.9999
# 555  31.12.9999
# 556  31.12.9999
# 557  31.12.9999
# 558  31.12.9999
# 559  31.12.9999
# 560  31.12.9999
# 561  31.12.9999
# 562  31.12.9999
# 563  31.12.9999
# 564  31.12.9999
# 565  31.12.9999
# 566  31.12.9999
# 567  31.12.9999
# 568  31.12.9999
# 569  31.12.9999
# 570  31.12.9999
# 571  31.12.9999
# 572  31.12.9999
# 573  31.12.9999
# 574  31.12.9999
#
# [575 rows x 16 columns]

# %%
df_cities_NIS.to_csv('cities_NIS_dataset.csv',index=False)
